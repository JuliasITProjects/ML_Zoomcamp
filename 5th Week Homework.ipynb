# %%
import json
import pickle
import pandas as pd
df = pd.read_csv("D:/MLZoomcamp/week5/dataset/bank.csv", sep=";")

#Question 1: What's the version of pipenv you installed? Answer: version 2023.10.3

#pip install pipenv -q
#pipenv --version


#Question 2: What's the first hash for scikit-learn you get in Pipfile.lock? Answer: e0d12a0331eb3926e2e7c7c37be9118ab3619b518475b3c3897cdb40da98d9d9

#open cmd prompt

# Create a new directory for your homework
#mkdir credit_scoring

# Navigate to the homework directory
#cd credit_scoring

# Initialize a Pipenv environment
#pipenv install

# Install Scikit-Learn version 1.3.1
#pipenv install scikit-learn==1.3.1


#Question 3: What's the probability that this client will get a credit?
dv_file_path = 'S:/ML Course/Homework Week 5/dataset/dv.bin'
model_file_path = 'S:/ML Course/Homework Week 5/dataset/model1.bin'

# Load the models
with open('S:/ML Course/Homework Week 5/dataset/dv.bin', 'rb') as dv_file:
    dv = pickle.load(dv_file)

with open('S:/ML Course/Homework Week 5/dataset/model1.bin', 'rb') as model_file:
    model = pickle.load(model_file)

# Define the client data
client = {"job": "retired", "duration": 445, "poutcome": "success"}

# Transform client data and make a prediction
X = dv.transform([client])
proba = model.predict_proba(X)[0][1]

print(f"The probability that this client will get a credit: {proba:.3f}")

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()
    X_data = dv.transform([data])
    proba = model.predict_proba(X_data)[:, 1][0]  # Get the probability of class 1
    return jsonify({'probability': proba})

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=8080)

    
#Question 4: What's the probability that this client will get a credit?. Answer: 0.140

#pip install waitress
#create new py file with the name ''app''
#in cmd, go to the project directory, should look like S:\PythonProjects\HW5\venv

#write code:

from flask import Flask, request, jsonify
import pickle
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

app = Flask(__name__)

# Load the DictVectorizer and model
with open('S:/ML Course/Homework Week 5/dataset/dv.bin', "rb") as dv_file:
    dv = pickle.load(dv_file)

with open('S:/ML Course/Homework Week 5/dataset/model1.bin', "rb") as model_file:
    model = pickle.load(model_file)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()
    X_data = dv.transform([data])
    proba = model.predict_proba(X_data)[:, 1][0]  # Get the probability of class 1
    return jsonify({'probability': proba})

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=8080)


#run the code
#in cmd, write waitress-serve --host=0.0.0.0 --port=8080 app:app
#open jupyter notebook
#write code:
import requests

# Replace "YOUR_URL" with the URL where your Flask app is running
url = "http://127.0.0.1:8080/predict"  # Example URL for a local Flask app

client = {"job": "unknown", "duration": 270, "poutcome": "failure"}
response = requests.post(url, json=client).json()
probability = response['probability']

print(f"The probability that this client will get credit: {probability:.3f}")


#Question 5: So what's the size of this base image?. Answer: 147MB
#open cmd prompt
# write:
# docker
# docker pull svizor/zoomcamp-model:3.10.12-slim
# docker images
# Out:
# The probability that this client will get a credit: 0.902
# S:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator DictVectorizer from version 1.3.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# S:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.3.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...
